# %%
#1. Handle Data

import csv

with open('C:\\Users\\Admin\\Desktop\\IA\\iris.data.txt', 'r') as csvfile:
    
    lines = csv.reader(csvfile)

    for row in lines:
        
        print(', '.join(row))
# Out:
# 5.1, 3.5, 1.4, 0.2, Iris-setosa
# 4.9, 3.0, 1.4, 0.2, Iris-setosa
# 4.7, 3.2, 1.3, 0.2, Iris-setosa
# 4.6, 3.1, 1.5, 0.2, Iris-setosa
# 5.0, 3.6, 1.4, 0.2, Iris-setosa
# 5.4, 3.9, 1.7, 0.4, Iris-setosa
# 4.6, 3.4, 1.4, 0.3, Iris-setosa
# 5.0, 3.4, 1.5, 0.2, Iris-setosa
# 4.4, 2.9, 1.4, 0.2, Iris-setosa
# 4.9, 3.1, 1.5, 0.1, Iris-setosa
# 5.4, 3.7, 1.5, 0.2, Iris-setosa
# 4.8, 3.4, 1.6, 0.2, Iris-setosa
# 4.8, 3.0, 1.4, 0.1, Iris-setosa
# 4.3, 3.0, 1.1, 0.1, Iris-setosa
# 5.8, 4.0, 1.2, 0.2, Iris-setosa
# 5.7, 4.4, 1.5, 0.4, Iris-setosa
# 5.4, 3.9, 1.3, 0.4, Iris-setosa
# 5.1, 3.5, 1.4, 0.3, Iris-setosa
# 5.7, 3.8, 1.7, 0.3, Iris-setosa
# 5.1, 3.8, 1.5, 0.3, Iris-setosa
# 5.4, 3.4, 1.7, 0.2, Iris-setosa
# 5.1, 3.7, 1.5, 0.4, Iris-setosa
# 4.6, 3.6, 1.0, 0.2, Iris-setosa
# 5.1, 3.3, 1.7, 0.5, Iris-setosa
# 4.8, 3.4, 1.9, 0.2, Iris-setosa
# 5.0, 3.0, 1.6, 0.2, Iris-setosa
# 5.0, 3.4, 1.6, 0.4, Iris-setosa
# 5.2, 3.5, 1.5, 0.2, Iris-setosa
# 5.2, 3.4, 1.4, 0.2, Iris-setosa
# ...

# %%
import random

def loadDataset(filename, split, trainingSet=[] , testSet=[]):

    with open(filename, 'r') as csvfile:

        lines = csv.reader(csvfile)

        dataset = list(lines)

        for x in range(len(dataset)-1):

            for y in range(4):

                dataset[x][y] = float(dataset[x][y])

            if random.random() < split:
                
                trainingSet.append(dataset[x])
                
            else:
                
                testSet.append(dataset[x])

# %%
trainingSet=[]

testSet=[]

loadDataset('C:\\Users\\Admin\\Desktop\\IA\\iris.data.txt', 0.66, trainingSet, testSet)

print ('Train: ' + repr(len(trainingSet)))

print ('Test: ' + repr(len(testSet)) )
# Out:
# Train: 98
# Test: 51

# %%
#2. Similarity

import math

def euclideanDistance(instance1, instance2, length):
    
    distance=0
    
    for x in range(length):
        
        distance += pow((instance1[x]-instance2[x]), 2)
        
    return math.sqrt(distance)

data1 = [2, 2, 2, 'a']

data2 = [4, 4, 4, 'b']

distance = euclideanDistance(data1, data2, 3)

print('Distance: ' + repr(distance))
# Out:
# Distance: 3.4641016151377544

# %%
#3. Neighbors

import operator

def getNeighbors(trainingSet, testInstance, k):

    distances = []

    length = len(testInstance)-1

    for x in range(len(trainingSet)):

        dist = euclideanDistance(testInstance, trainingSet[x], length)

        distances.append((trainingSet[x], dist))

    distances.sort(key=operator.itemgetter(1))

    neighbors = []

    for x in range(k):

        neighbors.append(distances[x][0])

    return neighbors



trainSet = [[2, 2, 2, 'a'], [4, 4, 4, 'b']]

testInstance = [5, 5, 5]

k = 1

neighbors = getNeighbors(trainSet, testInstance, 1)

print(neighbors)
# Out:
# [[4, 4, 4, 'b']]

# %%
#4. Response

import operator

def getResponse(neighbors):

    classVotes = {}

    for x in range(len(neighbors)):

        response = neighbors[x][-1] 
        
        if response in classVotes:
        
           classVotes[response]+= 1
            
        else:
        
           classVotes[response]= 1
            
    sortedVotes = sorted(classVotes.items(), key=operator.itemgetter(1), reverse=True)

    return sortedVotes[0][0]



neighbors = [[1,1,1,'a'], [2,2,2,'a'], [3,3,3,'b']]

response = getResponse(neighbors)

print(response)
# Out:
# a

# %%
#5. Accuracy

def getAccuracy(testSet, predictions):
    
    correct=0
    
    for x in range(len(testSet)):
        
        if testSet[x][-1] in predictions[x]:
            
            correct= correct+1
            
    return (correct/float(len(testSet))) * 100.0
        
testSet = [[1,1,1,'a'], [2,2,2,'a'], [3,3,3,'b']]

predictions = ['a', 'a', 'a']

accuracy = getAccuracy(testSet, predictions)

print(accuracy)
# Out:
# 66.66666666666666

# %%
#6. Main

def main():
    
    trainingSet=[]

    testSet=[]

    loadDataset('C:\\Users\\Admin\\Desktop\\IA\\iris.data.txt', 0.66, trainingSet, testSet)

    print ('Train: ' + repr(len(trainingSet)))

    print ('Test: ' + repr(len(testSet)) )
    
    predictions=[]
    
    k=3
    
    for x in range (len(testSet)):
        
        neighbors = getNeighbors(trainingSet, testSet[x], k)
        
        result = getResponse(neighbors)
        
        predictions.append(result)
            
        print('> predicted='+repr(result)+'actual='+repr([x][-1]))
        
    accurancy = getAccuracy(testSet, predictions)
    
    print('Accurancy:' + repr(accurancy)+'%')
        
main()
# Out:
# Train: 98
# Test: 51
# > predicted='Iris-setosa'actual=0
# > predicted='Iris-setosa'actual=1
# > predicted='Iris-setosa'actual=2
# > predicted='Iris-setosa'actual=3
# > predicted='Iris-setosa'actual=4
# > predicted='Iris-setosa'actual=5
# > predicted='Iris-setosa'actual=6
# > predicted='Iris-setosa'actual=7
# > predicted='Iris-setosa'actual=8
# > predicted='Iris-setosa'actual=9
# > predicted='Iris-setosa'actual=10
# > predicted='Iris-setosa'actual=11
# > predicted='Iris-setosa'actual=12
# > predicted='Iris-setosa'actual=13
# > predicted='Iris-setosa'actual=14
# > predicted='Iris-setosa'actual=15
# > predicted='Iris-setosa'actual=16
# > predicted='Iris-setosa'actual=17
# > predicted='Iris-versicolor'actual=18
# > predicted='Iris-versicolor'actual=19
# > predicted='Iris-versicolor'actual=20
# > predicted='Iris-versicolor'actual=21
# > predicted='Iris-versicolor'actual=22
# > predicted='Iris-versicolor'actual=23
# > predicted='Iris-versicolor'actual=24
# ...

# %% [markdown]
# #7. Another distance metric
#
# Minkowski Distance: A generalization that includes both Euclidean and Manhattan distances as special cases. It is defined as D = (Σ|i=1 to n| (|x1i - x2i|)^p)^(1/p), where p is a parameter. When p = 1, it's equivalent to the Manhattan distance, and when p = 2, it's the Euclidean distance.
#
# Cosine Similarity: Often used in text analysis and information retrieval, it measures the cosine of the angle between two vectors. It quantifies the similarity of the directions of two vectors, regardless of their magnitudes.
#
# Hamming Distance: Used to measure the difference between two strings of equal length. It counts the number of positions at which the corresponding elements are different.
#
# Jaccard Distance: Commonly used in set theory and text analysis, it measures the dissimilarity between two sets. It is defined as the size of the intersection divided by the size of the union of the sets.
#
# Mahalanobis Distance: Takes into account the correlation between variables and is often used in multivariate statistical analysis. It is a generalized form of the Euclidean distance.
